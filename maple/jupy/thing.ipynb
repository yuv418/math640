# %%
MyIfactor(n) := proc(a) local n: 
od:

# %%
plot(sin(x))
# Out:
# kilobytes used=3604, alloc=9776, time=0.23

# %%
ithprime(123)
# Out:
# $$677$$

# %%
factor(x^2 + 3*x)
# Out:
# $$x \left(x +3\right)$$
